# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import time
from scipy import stats
from scipy.stats import norm, probplot
import xgboost as xgb

from sklearn.pipeline import Pipeline, FeatureUnion, make_pipeline
from sklearn.preprocessing import PolynomialFeatures,MaxAbsScaler, MinMaxScaler, FunctionTransformer, OneHotEncoder, KBinsDiscretizer
from sklearn.decomposition import PCA, TruncatedSVD
from sklearn.base import BaseEstimator,TransformerMixin
from sklearn.feature_selection import VarianceThreshold
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.feature_extraction.text import CountVectorizer 

from sklearn.model_selection import cross_val_score, train_test_split as split

from sklearn.neighbors import KNeighborsRegressor as KNNR
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, RandomTreesEmbedding

from sklearn.metrics import roc_curve, mean_absolute_error, make_scorer
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Exploration and Preprocessing

# %%
data = pd.read_csv('./input/airbnbs.csv')

# %%
data.head(3)
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0   70820   https://www.airbnb.com/rooms/70820  20231225202604   2023-12-25
# 1  117122  https://www.airbnb.com/rooms/117122  20231225202604   2023-12-25
# 2  176306  https://www.airbnb.com/rooms/176306  20231225202604   2023-12-25
#
#         source                                               name  \
# 0  city scrape  Townhouse in Bristol · ★4.77 · 1 bedroom · 1 b...
# 1  city scrape  Condo in Bristol · ★4.96 · 1 bedroom · 1 bed ·...
# 2  city scrape  Townhouse in Bristol · ★4.79 · 1 bedroom · 1 b...
#
#    description                              neighborhood_overview  \
# 0          NaN  The neighbourhood is friendly and welcoming; m...
# 1          NaN  This area is on the water and has splendid vie...
# 2          NaN  Southville is pretty darn hip, frankly. North ...
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/b33c30be-56a0...   360195  ...
# 1  https://a0.muscache.com/pictures/13b41142-0946...   591555  ...
# 2  https://a0.muscache.com/pictures/e1e7fdfc-9db5...   708175  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.94                   4.76                4.76
# 1                        4.99                   4.97                4.88
# 2                        4.94                   4.78                4.74
#
#   license instant_bookable calculated_host_listings_count  \
# 0     NaN                f                              5
# 1     NaN                f                              1
# 2     NaN                f                              1
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           0
# 1                                           0
# 2                                           0
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            5
# 1                                            1
# 2                                            1
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              1.52
# 1                                           0              1.18
# 2                                           0              0.39
#
# [3 rows x 75 columns]

# %%
data.shape
# Out:
# (2556, 75)

# %%
data = data.dropna(axis=1, how='all')

unique_counts = data.nunique()

data = data.loc[:, unique_counts > 1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data = data.dropna(axis=1, how='all')
#
# NameError: name 'data' is not defined

# %%
data.shape
# Out:
# (2556, 67)

# %%
# delect the rows without price
data = data.dropna(subset=['price'])

# %% [markdown]
# The data we have consists of floats, integers, booleans and strings (some of which should be boolean, some should be floats, some should be handled as single entities). Also, for some features we have NANs that will have to be filled using tranfromers.

# %%
# 要删除的列名列表
columns_to_drop = ['id', 'listing_url', 'last_scraped', 'source', 
                   'picture_url', 'host_id', 'host_url', 'host_location', 
                   'host_about', 'host_thumbnail_url', 'host_picture_url',
                   'neighbourhood','host_name']

# 仅删除存在的列
existing_columns_to_drop = [col for col in columns_to_drop if col in data.columns]

# 删除列
data = data.drop(existing_columns_to_drop, axis=1)

# %%
column_names = data.columns
print(column_names)
# Out:
# Index(['name', 'neighborhood_overview', 'host_since', 'host_response_time',
#        'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified',
#        'neighbourhood_cleansed', 'latitude', 'longitude', 'property_type',
#        'room_type', 'accommodates', 'bathrooms_text', 'beds', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'has_availability', 'availability_30',
#        'availability_60', 'availability_90', 'availability_365',
#        'calendar_last_scraped', 'number_of_reviews', 'number_of_reviews_ltm',
#        'number_of_reviews_l30d', 'first_review', 'last_review',
#        'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'instant_bookable',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month'],
#       dtype='object')

# %%
# see what variables are in the data
pd.set_option('display.max_colwidth', 0)
data[[ 'host_since',
       'host_response_time', 'host_response_rate', 'host_acceptance_rate',
       'host_is_superhost', 'host_neighbourhood', 'host_listings_count',
       'host_total_listings_count', 'host_verifications',
       'host_has_profile_pic', 'host_identity_verified',
       'neighbourhood_cleansed', 'latitude', 'longitude', 'property_type',
       'room_type', 'accommodates', 'bathrooms_text', 'beds', 'price',
       'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
       'maximum_minimum_nights', 'minimum_maximum_nights',
       'maximum_maximum_nights', 'minimum_nights_avg_ntm',
       'maximum_nights_avg_ntm', 'has_availability', 'availability_30',
       'availability_60', 'availability_90', 'availability_365',
       'calendar_last_scraped', 'number_of_reviews', 'number_of_reviews_ltm',
       'number_of_reviews_l30d', 'first_review', 'last_review',
       'review_scores_rating', 'review_scores_accuracy',
       'review_scores_cleanliness', 'review_scores_checkin',
       'review_scores_communication', 'review_scores_location',
       'review_scores_value', 'instant_bookable',
       'calculated_host_listings_count',
       'calculated_host_listings_count_entire_homes',
       'calculated_host_listings_count_private_rooms',
       'calculated_host_listings_count_shared_rooms', 'reviews_per_month']].agg(['unique']).transpose()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              unique
# host_since                                    [2011-01-24, 2011-05-15, 2011-06-16, 2012-01-08, 2012-03-18, 2012-03-17, 2012-03-29, 2012-04-08, 2012-04-09, 2012-06-24, 2012-10-28, 2013-03-30, 2013-05-14, 2013-05-18, 2013-05-19, 2013-06-27, 2013-07-03, 2013-01-03, 2013-09-04, 2013-10-17, 2013-04-13, 2014-01-18, 2014-02-23, 2014-04-02, 2013-07-19, 2014-06-29, 2014-06-30, 2011-06-01, 2014-07-18, 2014-07-31, 2014-08-18, 2014-08-27, 2012-11-14, 2014-09-11, 2014-10-02, 2013-07-20, 2013-09-03, 2014-11-10, 2013-02-15, 2014-12-12, 2015-02-05, 2014-08-03, 2015-02-23, 2015-01-05, 2013-12-01, 2015-03-20, 2015-01-09, 2014-09-13, 2013-05-12, 2015-02-10, 2014-03-30, 2014-07-14, 2014-09-10, 2015-03-24, 2014-02-17, 2015-07-04, 2015-06-30, 2014-04-17, 2015-07-18, 2014-05-24, 2015-06-11, 2013-02-12, 2015-08-06, 2015-08-09, 2015-07-05, 2015-07-30, 2014-02-02, 2015-08-13, 2015-07-24, 2013-08-01, 2015-09-25, 2015-10-07, 2015-10-12, 2015-10-18, 2015-09-28, 2013-10-29, 2015-05-08, 2015-09-05, 2013-07-17, 2015-11-10, 2015-11-11, 2015-02-18, 2015-06-03, 2017-05-14, 2014-07-25, 2014-06-20, 2016-01-03, 2013-07-31, 2014-09-01, 2013-11-23, 2015-06-09, 2016-02-24, 2016-02-27, 2016-03-04, 2016-01-05, 2015-03-13, 2013-12-17, 2016-03-16, 2015-11-03, 2016-04-02, ...]
# host_response_time                            [within an hour, within a few hours, nan, within a day, a few days or more]
# host_response_rate                            [100%, nan, 90%, 70%, 40%, 91%, 83%, 67%, 0%, 80%, 92%, 86%, 50%, 97%, 30%, 98%, 20%, 94%, 57%, 96%, 60%, 89%, 75%, 95%, 88%, 74%, 10%, 71%, 82%, 99%, 11%, 65%, 78%, 68%]
# host_acceptance_rate                          [94%, 87%, 57%, 100%, 93%, 77%, 81%, 73%, 98%, 97%, 88%, 80%, 75%, 83%, 0%, 59%, 89%, 70%, 72%, nan, 63%, 91%, 60%, 66%, 96%, 58%, 71%, 99%, 20%, 95%, 50%, 56%, 74%, 86%, 10%, 84%, 90%, 53%, 79%, 40%, 44%, 78%, 92%, 82%, 29%, 25%, 46%, 85%, 67%, 13%, 33%, 37%, 52%, 55%, 62%, 49%, 69%, 43%, 19%, 21%, 76%, 61%, 64%, 48%, 65%, 68%, 18%, 47%, 26%, 31%, 32%, 38%, 16%, 42%, 41%, 35%, 39%, 11%, 54%, 36%, 30%, 51%, 22%, 14%, 17%, 8%, 34%, 27%]
# host_is_superhost                             [f, t, nan]
# host_neighbourhood                            [nan, Hampstead, Shoreditch, Tooting Bec, Forest Hill, Flean More, Bow, Quaid Block, Pimlico, Crone Upper, LB of Waltham Forest, South of Nevsky, Mechanicsville, Dublin Docklands, Crec'heur, Northeast Washington, Brent Cross, North Maida Vale, Lekki Penninsula II, South Kensington, Temple Bar]
# host_listings_count                           [5, 2, 3, 1, 4, 7, 6, 194, 19, 55, 22, 70, 11, 9, 37, 8, 65, 1382, 10, 231, 160, 14, 357, 46, 2442, 27, 41, 36, 56, 26, 20, 48, 16, 77, 13, 125, 45, 1299, 31, 39, 18, 12, 38, 17]
# host_total_listings_count                     [7, 2, 3, 1, 4, 6, 5, 10, 8, 428, 27, 9, 69, 31, 115, 11, 34, 16, 15, 40, 13, 52, 44, 209, 5280, 12, 24, 451, 217, 14, 660, 37, 47, 22, 5529, 28, 48, 36, 63, 41, 160, 17, 89, 20, 139, 82, 1744, 91, 39, 42, 21, 18, 43]
# host_verifications                            [['email', 'phone', 'work_email'], ['email', 'phone'], ['phone'], ['phone', 'work_email'], []]
# host_has_profile_pic                          [t, f]
# host_identity_verified                        [t, f]
# neighbourhood_cleansed                        [Windmill Hill, Hotwells & Harbourside, Southville, Easton, Brislington West, Redland, Westbury-on-Trym & Henleaze, Ashley, Lawrence Hill, Clifton, Knowle, Avonmouth & Lawrence Weston, Stoke Bishop, Eastville, Henbury & Brentry, Cotham, Stockwood, Clifton Down, St George West, Bishopston & Ashley Down, Horfield, Brislington East, Bedminster, Southmead, Central, Lockleaze, Frome Vale, St George Troopers Hill, Hillfields, Hengrove & Whitchurch Park, St George Central, Hartcliffe & Withywood, Filwood, Bishopsworth]
# latitude                                      [51.43843, 51.44976, 51.44174, 51.46487, 51.44444, 51.477821350097656, 51.49491, 51.46769, 51.46547, 51.4738, 51.45591, 51.45524, 51.47461, 51.4636, 51.45169, 51.43867804381247, 51.48503, 51.45919, 51.47269, 51.47402, 51.51348, 51.46699, 51.47175, 51.46774, 51.45915, 51.45916, 51.46664, 51.46949, 51.41205, 51.4628, 51.46566, 51.4647, 51.4451, 51.465, 51.4506, 51.46993, 51.46729, 51.46167, 51.44264, 51.44716, 51.4644, 51.46495, 51.47656, 51.46166, 51.47476, 51.46777, 51.45914, 51.44247817993164, 51.47416, 51.46977, 51.47619, 51.43784, 51.44166, 51.45347, 51.46541, 51.44274, 51.47277, 51.46514, 51.4505, 51.47104, 51.46669, 51.45663, 51.45903, 51.47394, 51.43908, 51.46458, 51.4516, 51.44856, 51.44885, 51.47752329999999, 51.4564, 51.485443, 51.45784, 51.47926, 51.42945, 51.47883, 51.47105, 51.49529, 51.46688, 51.46258, 51.47713, 51.43805, 51.46707, 51.45494, 51.43871, 51.44263, 51.43072, 51.47828, 51.46444, 51.50134, 51.46571, 51.47542, 51.4676, 51.49464, 51.4544, 51.45141, 51.49514, 51.47264, 51.48624, 51.47366, ...]
# longitude                                     [-2.59183, -2.61, -2.60297, -2.5569, -2.55783, -2.5919950008392334, -2.61879, -2.5825, -2.58458, -2.60615, -2.57803, -2.62168, -2.60433, -2.57788, -2.62087, -2.5671489772985154, -2.67242, -2.57566, -2.64089, -2.54735, -2.59961, -2.59563, -2.56267, -2.58777, -2.62554, -2.62558, -2.58431, -2.58385, -2.55552, -2.56775, -2.60942, -2.61036, -2.60566, -2.57984, -2.60721, -2.61109, -2.62091, -2.5966, -2.58013, -2.6039, -2.60411, -2.60387, -2.55667, -2.58571, -2.62736, -2.59495, -2.60963, -2.607893943786621, -2.59722, -2.61086, -2.59096, -2.59526, -2.6081, -2.61703, -2.5845, -2.60775, -2.59178, -2.61445, -2.62156, -2.58119, -2.61031, -2.58261, -2.55053, -2.5875, -2.59412, -2.59522, -2.61645, -2.61658, -2.61513, -2.6063242, -2.61696, -2.672908, -2.61117, -2.58416, -2.56371, -2.58503, -2.58752, -2.57997, -2.61464, -2.56678, -2.58791, -2.54173, -2.59213, -2.61462, -2.54445, -2.6113, -2.60603, -2.56403, -2.55455, -2.5879, -2.60671, -2.56256, -2.54833, -2.61501, -2.61207, -2.59404, -2.59257, -2.61095, -2.63799, -2.58871, ...]
# property_type                                 [Private room in townhouse, Private room in condo, Private room in home, Entire rental unit, Private room in rental unit, Entire home, Barn, Private room in bed and breakfast, Entire guesthouse, Entire townhouse, Entire loft, Tiny home, Entire condo, Entire guest suite, Entire serviced apartment, Private room in bungalow, Houseboat, Private room in loft, Room in serviced apartment, Entire place, Entire cottage, Camper/RV, Private room in castle, Entire cabin, Private room in serviced apartment, Private room in tiny home, Private room in yurt, Private room in hostel, Private room in guest suite, Room in boutique hotel, Room in hotel, Religious building, Entire villa, Private room in camper/rv, Private room in cabin, Room in aparthotel, Private room, Entire vacation home, Private room in hut, Treehouse, Private room in casa particular, Private room in guesthouse, Entire bungalow, Shared room in rental unit]
# room_type                                     [Private room, Entire home/apt, Hotel room, Shared room]
# accommodates                                  [2, 1, 3, 5, 4, 10, 8, 9, 7, 6, 16, 14, 13, 15, 12, 11]
# bathrooms_text                                [1 shared bath, 2.5 shared baths, 1.5 shared baths, 1 private bath, 1 bath, 2 baths, 1.5 baths, 4.5 baths, Half-bath, 2.5 baths, 3 baths, 3.5 baths, 3 shared baths, Shared half-bath, 2 shared baths, 5 baths, 7 baths, 0 shared baths, 4 baths, 6 baths, 0 baths, nan, 15 baths]
# beds                                          [1.0, 2.0, 3.0, 4.0, 6.0, nan, 5.0, 8.0, 14.0, 21.0, 9.0, 15.0, 7.0, 12.0, 10.0, 18.0, 17.0, 11.0, 25.0]
# price                                         [$44.00, $111.00, $35.00, $38.00, $52.00, $80.00, $110.00, $215.00, $59.00, $153.00, $145.00, $41.00, $37.00, $40.00, $42.00, $600.00, $25.00, $23.00, $88.00, $36.00, $51.00, $46.00, $50.00, $20.00, $28.00, $49.00, $90.00, $54.00, $275.00, $70.00, $100.00, $75.00, $95.00, $61.00, $150.00, $86.00, $47.00, $200.00, $55.00, $63.00, $69.00, $60.00, $300.00, $85.00, $114.00, $79.00, $350.00, $30.00, $84.00, $189.00, $71.00, $57.00, $65.00, $45.00, $48.00, $27.00, $250.00, $67.00, $179.00, $64.00, $120.00, $31.00, $58.00, $164.00, $68.00, $104.00, $82.00, $81.00, $34.00, $160.00, $181.00, $117.00, $212.00, $76.00, $199.00, $219.00, $464.00, $78.00, $56.00, $99.00, $74.00, $66.00, $140.00, $170.00, $573.00, $83.00, $39.00, $503.00, $130.00, $89.00, $262.00, $125.00, $1,050.00, $320.00, $121.00, $128.00, $685.00, $139.00, $98.00, $148.00, ...]
# minimum_nights                                [3, 1, 5, 6, 2, 4, 7, 20, 90, 30, 10, 12, 28, 100, 9, 14, 186, 29, 32, 31, 21, 120, 22, 110, 365, 49, 15, 60, 180, 25, 77]
# maximum_nights                                [21, 28, 32, 1125, 100, 180, 30, 1124, 7, 14, 31, 90, 45, 350, 16, 5, 50, 365, 18, 10, 60, 2, 17, 4, 35, 75, 3, 6, 120, 12, 70, 730, 19, 8, 80, 15, 26, 150, 62, 300, 20, 1121, 200, 999, 13, 25, 40, 56, 360, 121, 111, 55, 99, 1, 370, 375, 140, 49, 9, 183, 1000, 11, 29, 24, 42, 61, 186, 220, 89, 77, 177, 210]
# minimum_minimum_nights                        [3.0, 1.0, 5.0, 6.0, 2.0, 7.0, 4.0, 20.0, 90.0, 10.0, 12.0, 31.0, 28.0, 100.0, 30.0, 11.0, 14.0, 186.0, 29.0, 32.0, 21.0, 120.0, 22.0, 110.0, 365.0, 49.0, 15.0, 60.0, 180.0, 77.0]
# maximum_minimum_nights                        [3.0, 1.0, 5.0, 6.0, 2.0, 4.0, 7.0, 20.0, 90.0, 30.0, 10.0, 12.0, 31.0, 28.0, 14.0, 21.0, 100.0, 9.0, 186.0, 65.0, 27.0, 29.0, 32.0, 60.0, 120.0, 22.0, 110.0, 365.0, 50.0, 49.0, 15.0, 24.0, 180.0, 25.0, 206.0, 77.0]
# minimum_maximum_nights                        [21.0, 28.0, 32.0, 1125.0, 100.0, 180.0, 30.0, 7.0, 14.0, 31.0, 90.0, 45.0, 350.0, 16.0, 5.0, 365.0, 18.0, 2.0, 10.0, 17.0, 4.0, 60.0, 1124.0, 75.0, 1.0, 35.0, 3.0, 6.0, 120.0, 12.0, 730.0, 19.0, 80.0, 15.0, 26.0, 50.0, 300.0, 20.0, 200.0, 24.0, 363.0, 999.0, 99.0, 122.0, 150.0, 13.0, 25.0, 56.0, 360.0, 250.0, 40.0, 111.0, 55.0, 370.0, 140.0, 49.0, 183.0, 8.0, 731.0, 11.0, 62.0, 29.0, 42.0, 61.0, 186.0, 220.0, 89.0, 77.0, 177.0, 210.0, 70.0]
# maximum_maximum_nights                        [21.0, 28.0, 32.0, 1125.0, 100.0, 180.0, 30.0, 7.0, 14.0, 31.0, 90.0, 45.0, 350.0, 16.0, 5.0, 365.0, 18.0, 2.0, 10.0, 17.0, 4.0, 60.0, 1124.0, 75.0, 999.0, 35.0, 3.0, 6.0, 120.0, 12.0, 730.0, 19.0, 80.0, 15.0, 26.0, 50.0, 300.0, 20.0, 200.0, 24.0, 363.0, 99.0, 150.0, 13.0, 25.0, 56.0, 360.0, 40.0, 111.0, 70.0, 1.0, 370.0, 140.0, 49.0, 183.0, 8.0, 731.0, 11.0, 62.0, 29.0, 42.0, 61.0, 186.0, 220.0, 89.0, 77.0, 177.0, 210.0]
# minimum_nights_avg_ntm                        [3.0, 1.0, 5.0, 6.0, 2.0, 4.0, 7.0, 20.0, 90.0, 29.8, 2.6, 1.4, 5.9, 2.1, 1.3, 10.0, 12.0, 1.1, 4.3, 31.0, 6.9, 3.1, 2.7, 28.0, 12.3, 18.0, 4.1, 3.3, 100.0, 2.5, 8.9, 3.5, 2.2, 2.9, 1.9, 30.0, 13.7, 2.3, 4.9, 2.8, 13.4, 14.0, 186.0, 6.1, 3.9, 17.1, 1.6, 5.7, 3.8, 2.4, 23.7, 29.0, 1.7, 3.2, 13.5, 3.7, 9.1, 1.8, 17.6, 12.9, 32.0, 23.6, 3.6, 17.0, 1.5, 38.9, 6.3, 120.0, 22.0, 67.8, 110.0, 365.0, 9.9, 11.4, 4.8, 1.2, 5.5, 3.4, 27.9, 49.0, 15.0, 25.3, 60.0, 19.8, 13.0, 180.0, 4.7, 6.7, 18.4, 24.6, 6.2, 4.4, 5.1, 53.8, 6.6, 6.5, 18.2, 5.6, 23.5, 53.2, ...]
# maximum_nights_avg_ntm                        [21.0, 28.0, 32.0, 1125.0, 100.0, 180.0, 30.0, 7.0, 14.0, 31.0, 90.0, 45.0, 350.0, 16.0, 5.0, 365.0, 18.0, 2.0, 10.0, 17.0, 4.0, 60.0, 1124.0, 75.0, 734.3, 598.6, 35.0, 3.0, 6.0, 120.0, 12.0, 730.0, 19.0, 43.9, 80.0, 15.0, 27.8, 1104.4, 917.4, 26.0, 1104.5, 22.1, 50.0, 300.0, 20.0, 1040.8, 200.0, 179.9, 888.7, 24.0, 569.8, 353.3, 363.0, 913.5, 911.1, 999.0, 177.4, 99.0, 153.3, 1071.1, 150.0, 187.7, 340.5, 1114.7, 13.0, 699.7, 25.0, 1078.7, 56.0, 360.0, 9.8, 592.0, 40.0, 111.0, 902.1, 57.9, 1073.7, 1.0, 370.0, 1081.3, 990.8, 844.0, 1112.1, 993.2, 593.9, 492.5, 140.0, 1099.8, 691.7, 1109.5, 49.0, 895.8, 58.6, 358.4, 826.4, 183.0, 641.1, 8.0, 1056.9, 731.0, ...]
# has_availability                              [t, f]
# availability_30                               [11, 26, 0, 30, 24, 10, 17, 18, 14, 1, 25, 15, 12, 20, 4, 28, 21, 27, 29, 2, 6, 16, 22, 5, 23, 13, 3, 19, 8, 9, 7]
# availability_60                               [11, 56, 17, 60, 0, 54, 40, 48, 4, 14, 18, 19, 55, 45, 6, 37, 10, 47, 50, 58, 51, 31, 57, 59, 2, 27, 42, 52, 53, 13, 12, 33, 8, 46, 32, 36, 22, 30, 3, 9, 35, 34, 24, 1, 7, 20, 21, 25, 39, 43, 44, 38, 26, 5, 41, 16, 15, 49, 28, 23, 29]
# availability_90                               [11, 86, 47, 90, 0, 84, 70, 17, 76, 34, 37, 48, 21, 85, 75, 6, 67, 10, 77, 80, 4, 88, 54, 87, 89, 39, 2, 57, 8, 66, 82, 63, 35, 83, 13, 14, 12, 23, 18, 29, 60, 52, 81, 3, 38, 59, 9, 71, 64, 61, 44, 1, 19, 20, 46, 74, 30, 78, 25, 24, 55, 56, 45, 73, 49, 7, 26, 33, 31, 5, 68, 65, 28, 58, 62, 27, 69, 42, 40, 79, 72, 50, 15, 53, 32, 41, 51, 36, 22, 43, 16]
# availability_365                              [11, 360, 137, 365, 0, 174, 160, 131, 323, 34, 270, 48, 144, 350, 58, 342, 206, 86, 167, 175, 235, 355, 309, 4, 178, 85, 329, 87, 89, 124, 2, 358, 237, 171, 345, 336, 82, 99, 88, 315, 147, 90, 179, 262, 13, 216, 42, 23, 113, 18, 110, 227, 364, 76, 335, 152, 327, 356, 3, 95, 363, 218, 114, 170, 17, 70, 59, 347, 259, 145, 166, 97, 71, 294, 230, 269, 339, 38, 81, 65, 83, 6, 303, 5, 1, 181, 19, 221, 20, 9, 136, 61, 57, 162, 30, 77, 343, 112, 73, 256, ...]
# calendar_last_scraped                         [2023-12-25, 2023-12-26]
# number_of_reviews                             [189, 180, 53, 34, 59, 84, 101, 330, 194, 436, 281, 473, 368, 388, 88, 52, 40, 246, 21, 15, 203, 276, 346, 154, 72, 452, 35, 91, 30, 109, 231, 43, 141, 44, 696, 19, 361, 168, 251, 424, 36, 149, 255, 420, 23, 16, 65, 332, 417, 636, 11, 46, 18, 63, 163, 62, 562, 584, 228, 13, 7, 14, 93, 0, 326, 3, 118, 47, 250, 460, 279, 143, 50, 221, 86, 137, 31, 211, 178, 33, 42, 131, 123, 71, 129, 441, 380, 4, 28, 105, 202, 1, 257, 68, 41, 57, 984, 80, 193, 497, ...]
# number_of_reviews_ltm                         [11, 9, 10, 3, 8, 12, 18, 4, 42, 43, 23, 45, 30, 19, 0, 24, 25, 54, 22, 2, 41, 1, 14, 26, 13, 17, 15, 33, 6, 44, 66, 5, 81, 106, 27, 46, 39, 21, 20, 16, 95, 7, 173, 28, 37, 56, 117, 137, 70, 62, 77, 52, 105, 58, 114, 29, 89, 36, 31, 47, 32, 67, 61, 55, 57, 34, 64, 40, 48, 69, 135, 182, 65, 35, 94, 80, 38, 50, 90, 78, 96, 85, 63, 72, 99, 79, 161, 113, 51, 68, 49, 201, 59, 174, 93, 115, 86, 123, 73, 76, ...]
# number_of_reviews_l30d                        [1, 0, 5, 3, 2, 4, 8, 6, 14, 12, 10, 9, 15, 7, 11, 16, 13]
# ...
# review_scores_rating                          [4.77, 4.96, 4.79, 4.65, 4.89, 4.64, 4.87, 4.9, 4.83, 4.86, 4.92, 4.85, 4.71, 4.5, 4.95, 4.88, 4.33, 4.82, 4.81, 4.68, 4.69, 4.53, 4.97, 4.67, 4.91, 4.75, 4.93, 4.74, 5.0, 4.8, 4.62, 4.54, 4.94, 4.76, 4.27, 4.7, 4.84, nan, 4.73, 4.78, 4.55, 4.98, 4.58, 4.32, 4.4, 4.57, 4.99, 4.44, 4.66, 4.47, 4.36, 4.31, 4.38, 4.51, 4.2, 4.28, 4.08, 4.43, 4.56, 4.61, 4.72, 4.42, 4.39, 4.6, 4.29, 4.63, 4.23, 4.13, 4.15, 4.24, 4.41, 4.34, 4.16, 4.3, 4.19, 4.46, 4.59, 4.52, 4.25, 4.35, 4.18, 3.25, 4.0, 4.45, 3.67, 4.07, 4.14, 4.22, 3.0, 4.48, 3.5, 3.56, 4.37, 3.55, 4.21, 4.09, 3.75, 3.33, 3.83, 4.17, ...]
# review_scores_accuracy                        [4.89, 4.94, 4.72, 4.84, 4.88, 4.57, 4.99, 4.91, 4.93, 4.98, 4.87, 4.86, 4.81, 4.67, 4.95, 4.6, 4.78, 4.9, 4.83, 4.85, 4.77, 4.96, 4.97, 4.92, 4.82, 5.0, 4.79, 4.74, 4.75, nan, 4.8, 4.63, 4.65, 4.46, 4.58, 4.73, 4.44, 4.7, 4.66, 4.69, 4.56, 4.55, 4.76, 4.4, 4.33, 4.71, 4.38, 4.64, 4.51, 4.61, 4.68, 4.42, 4.32, 4.25, 4.49, 4.48, 4.24, 4.0, 3.5, 4.2, 4.35, 4.26, 4.5, 4.52, 3.0, 4.21, 4.62, 4.59, 4.39, 3.89, 4.47, 3.55, 4.45, 4.53, 4.27, 3.38, 4.19, 4.43, 4.14, 4.54, 4.34, 4.17, 3.2, 4.36, 4.09, 4.1, 4.37, 4.28, 3.33, 1.0, 3.75, 2.5, 3.79, 3.86, 4.11, 3.67, 4.29, 4.22]
# review_scores_cleanliness                     [4.68, 4.98, 4.46, 4.74, 4.91, 4.89, 4.84, 4.69, 4.97, 4.82, 4.59, 4.86, 4.93, 4.94, 4.6, 4.65, 4.07, 4.58, 4.85, 4.78, 4.77, 4.75, 4.87, 4.96, 4.95, 4.92, 4.62, 4.54, 5.0, 4.26, nan, 4.67, 4.79, 4.76, 4.44, 4.64, 4.42, 4.9, 4.8, 4.88, 4.45, 4.72, 4.63, 4.83, 3.0, 4.33, 4.57, 4.51, 4.4, 4.31, 4.71, 4.56, 4.49, 4.99, 4.81, 4.22, 4.35, 4.66, 4.55, 4.21, 4.53, 4.32, 4.28, 4.04, 3.83, 4.37, 4.73, 4.05, 4.61, 4.39, 4.29, 4.38, 4.1, 4.06, 4.15, 4.7, 4.5, 4.41, 4.11, 3.33, 4.36, 4.25, 4.52, 3.5, 3.62, 4.3, 4.09, 4.0, 4.24, 4.48, 4.47, 4.43, 4.2, 4.27, 4.34, 3.45, 4.18, 3.8, 4.13, 3.91, ...]
# review_scores_checkin                         [4.95, 5.0, 4.98, 4.94, 4.82, 4.96, 4.97, 4.93, 4.92, 4.87, 4.79, 4.86, 4.89, 4.63, 4.88, 4.9, 4.8, 4.99, 4.83, nan, 4.74, 4.85, 4.91, 4.78, 4.76, 4.67, 4.81, 4.72, 4.84, 4.58, 4.69, 4.77, 4.56, 4.42, 4.71, 4.75, 4.64, 4.73, 4.38, 4.7, 4.5, 4.3, 4.6, 4.61, 4.65, 4.55, 4.59, 4.54, 4.0, 4.62, 4.4, 4.68, 4.66, 4.53, 4.57, 4.31, 4.44, 4.19, 1.5, 4.33, 4.32, 4.11, 4.41, 4.09, 4.25, 4.2, 4.47, 3.83, 4.1, 4.48, 3.0, 3.79, 4.26, 4.29, 3.33, 4.46, 4.43, 4.15, 1.0, 2.5, 3.86, 3.5, 3.67, 2.82, 3.77, 3.75, 3.6, 2.0, 4.14]
# review_scores_communication                   [4.94, 4.99, 4.77, 4.93, 4.86, 4.97, 4.96, 4.98, 4.92, 4.95, 4.87, 4.85, 4.74, 4.91, 4.57, 4.81, 5.0, 4.89, 4.83, nan, 4.67, 4.82, 4.9, 4.71, 4.84, 4.8, 4.78, 4.75, 4.73, 4.68, 4.66, 4.88, 4.69, 4.64, 4.59, 4.76, 4.63, 4.52, 4.33, 4.79, 4.19, 4.65, 4.72, 4.56, 4.7, 4.39, 4.54, 4.62, 4.48, 4.43, 4.53, 4.5, 3.67, 2.5, 4.58, 4.0, 4.4, 4.6, 3.88, 4.23, 4.61, 4.47, 4.51, 4.38, 4.07, 4.14, 4.2, 4.22, 3.0, 4.12, 4.36, 4.55, 4.29, 3.5, 3.57, 4.41, 3.96, 4.37, 4.08, 4.42, 4.1, 3.8, 2.67, 4.11, 4.3, 3.9, 4.25, 4.46, 4.44, 1.0, 3.93, 4.49, 1.5, 3.75, 3.33, 3.73]
# review_scores_location                        [4.76, 4.97, 4.78, 4.81, 4.72, 4.59, 4.79, 4.87, 4.89, 4.93, 4.65, 4.99, 4.85, 4.41, 5.0, 4.8, 4.9, 4.57, 4.73, 4.75, 4.4, 4.67, 4.96, 4.82, 4.83, 4.94, 4.84, 4.92, 4.71, 4.91, 4.86, 4.66, 4.26, 4.88, nan, 4.95, 4.68, 4.38, 4.39, 4.98, 4.74, 4.61, 4.33, 4.6, 4.69, 4.63, 4.77, 4.09, 4.64, 4.5, 4.7, 4.1, 4.16, 3.95, 3.98, 4.44, 4.56, 4.52, 4.54, 4.58, 4.53, 4.62, 3.99, 4.42, 4.48, 3.67, 4.24, 4.46, 4.45, 4.55, 4.35, 3.77, 3.5, 4.3, 4.51, 4.29, 4.0, 4.49, 3.33, 4.36, 4.2, 3.63, 3.91, 3.19, 3.9, 3.96, 4.25, 4.17, 3.92, 3.93, 4.23, 4.05, 4.12, 4.14, 4.43, 4.11, 4.08, 4.04, 3.0, 4.47, ...]
# review_scores_value                           [4.76, 4.88, 4.74, 4.65, 4.84, 4.62, 4.9, 4.73, 4.85, 4.86, 4.68, 4.83, 4.91, 4.89, 4.87, 4.93, 4.47, 4.94, 4.81, 4.4, 4.82, 4.8, 4.7, 4.71, 4.63, 4.66, 4.92, 4.29, 4.75, 4.77, 4.72, 5.0, 4.79, 4.5, 4.33, nan, 4.67, 4.96, 4.69, 4.52, 4.78, 4.98, 4.61, 4.58, 4.59, 4.42, 4.37, 4.97, 4.27, 4.6, 4.99, 4.2, 4.19, 4.95, 4.41, 4.56, 4.3, 4.25, 4.31, 4.39, 4.18, 4.14, 4.54, 4.64, 4.46, 4.44, 4.57, 4.43, 4.24, 4.49, 4.22, 4.48, 4.45, 4.34, 4.03, 4.38, 4.12, 4.53, 3.88, 4.13, 4.35, 4.55, 4.06, 4.0, 3.25, 3.69, 4.28, 4.23, 4.51, 4.17, 4.1, 3.0, 4.32, 4.21, 4.08, 4.11, 3.73, 4.05, 4.36, 3.4, ...]
# instant_bookable                              [f, t]
# calculated_host_listings_count                [5, 1, 3, 2, 4, 6, 160, 13, 7, 47, 14, 57, 10, 17, 9, 18, 25, 8, 30, 21]
# calculated_host_listings_count_entire_homes   [0, 1, 2, 3, 5, 146, 9, 7, 47, 14, 6, 56, 4, 17, 18, 25, 30, 21, 13]
# calculated_host_listings_count_private_rooms  [5, 1, 2, 0, 3, 4, 6, 8]
# calculated_host_listings_count_shared_rooms   [0, 3]
# reviews_per_month                             [1.52, 1.18, 0.39, 0.43, 0.41, 0.6, 0.73, 2.33, 1.39, 3.07, 2.01, 3.5, 2.89, 2.98, 0.69, 0.4, 0.83, 1.94, 0.17, 0.12, 1.63, 0.94, 2.35, 2.91, 0.2, 1.32, 0.62, 3.9, 0.3, 0.9, 0.26, 0.96, 2.06, 1.58, 1.64, 1.49, 6.16, 0.36, 3.23, 1.68, 2.27, 3.82, 0.35, 1.37, 2.83, 3.93, 0.21, 0.72, 3.15, 3.94, 6.14, 0.11, 0.44, 0.34, 1.57, 0.61, 5.42, 5.77, 2.23, 0.13, 0.07, 0.14, 0.91, nan, 3.19, 0.18, 1.16, 1.13, 0.92, 2.47, 4.59, 2.76, 1.42, 0.5, 0.16, 2.21, 0.86, 0.32, 2.19, 0.24, 1.8, 1.4, 1.25, 0.78, 1.33, 4.47, 0.04, 1.45, 1.35, 0.31, 0.98, 1.86, 1.11, 2.13, 0.49, 3.63, 0.33, 2.72, 0.82, 0.53, ...]

# %%
# choose what we need

data_need = data[['neighbourhood_cleansed','host_is_superhost', 'property_type', 'room_type', 'bathrooms_text', 'beds', 'minimum_nights',
'number_of_reviews', 'number_of_reviews_ltm', 'last_review', 'first_review',
'review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 
'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 
'review_scores_value', 'instant_bookable', 'reviews_per_month', 'calculated_host_listings_count',
'calculated_host_listings_count_entire_homes', 'calculated_host_listings_count_private_rooms', 
'calculated_host_listings_count_shared_rooms','accommodates', 'price']]

# %%
def extract_info(name):
    # 提取评分
    rating = re.search(r'★(\d\.\d+)', name)
    rating = rating.group(1) if rating else None  # 提取数字部分

    # 提取卧室数量
    bedroom = re.search(r'(\d+) bedrooms?', name)
    bedroom = bedroom.group(1) if bedroom else None  # 提取数字部分

    return pd.Series([rating, bedroom])

# 假设你的 DataFrame 名为 data
data_need = data_need.copy()
# 确保操作是在原始 DataFrame 上进行
data_need[['rating', 'bedroom']] = data['name'].apply(extract_info)

data_need.head(3)
# Out:
#    neighbourhood_cleansed host_is_superhost              property_type  \
# 0  Windmill Hill           f                 Private room in townhouse
# 1  Hotwells & Harbourside  t                 Private room in condo
# 2  Southville              t                 Private room in townhouse
#
#       room_type    bathrooms_text  beds  minimum_nights  number_of_reviews  \
# 0  Private room  1 shared bath     1.0   3               189
# 1  Private room  2.5 shared baths  1.0   1               180
# 2  Private room  1 shared bath     1.0   5               53
#
#    number_of_reviews_ltm last_review  ... instant_bookable  reviews_per_month  \
# 0  11                     2023-11-29  ...  f                1.52
# 1  9                      2023-11-26  ...  f                1.18
# 2  10                     2023-12-12  ...  f                0.39
#
#    calculated_host_listings_count  \
# 0  5
# 1  1
# 2  1
#
#    calculated_host_listings_count_entire_homes  \
# 0  0
# 1  0
# 2  0
#
#    calculated_host_listings_count_private_rooms  \
# 0  5
# 1  1
# 2  1
#
#    calculated_host_listings_count_shared_rooms  accommodates    price rating  \
# 0  0                                            2             $44.00   4.77
# 1  0                                            2             $111.00  4.96
# 2  0                                            2             $35.00   4.79
#
#    bedroom
# 0  1
# 1  1
# 2  1
#
# [3 rows x 28 columns]

# %% [markdown]
# For property type we have 35 property types. To reduce number of features, property type is grouped in to 5 catagories: Apartment, House, Hotel1, Hotel2 and other, to use with OneHotEncoder
# (Note: encodging and PCA yealded worse results then "manual" grouping)

# %% [markdown]
# # Finding missing values

# %%
data_need['property_type'].value_counts()
# Out:
# Entire rental unit                    656
# Entire home                           398
# Private room in home                  363
# Entire condo                          209
# Entire serviced apartment             105
# Private room in townhouse             80
# Private room in rental unit           74
# Private room in condo                 59
# Entire townhouse                      50
# Private room in bed and breakfast     38
# Tiny home                             15
# Entire guest suite                    13
# Entire guesthouse                     12
# Entire cottage                        9
# Private room                          8
# Room in serviced apartment            8
# Entire loft                           8
# Camper/RV                             8
# Entire villa                          7
# Private room in tiny home             5
# Entire place                          4
# Entire cabin                          4
# Room in boutique hotel                3
# Room in hotel                         3
# Private room in guest suite           3
# Shared room in rental unit            3
# Room in aparthotel                    2
# Barn                                  2
# Private room in serviced apartment    2
# Private room in loft                  2
# Private room in guesthouse            2
# Treehouse                             2
# Entire bungalow                       1
# Private room in casa particular       1
# Private room in hut                   1
# Entire vacation home                  1
# Private room in yurt                  1
# Private room in hostel                1
# Private room in cabin                 1
# Private room in camper/rv             1
# Private room in bungalow              1
# Religious building                    1
# Houseboat                             1
# Private room in castle                1
# Name: property_type, dtype: int64

# %%
dict1 = {'Entire Home': ['Entire home', 'Entire townhouse', 'Entire guesthouse', 'Entire cottage', 
                    'Entire villa', 'Entire vacation home', 'Entire bungalow', 'Entire cabin', 
                    'Entire loft'],
        'Entire Apartment': ['Entire rental unit', 'Entire condo', 'Entire serviced apartment', 
                         'Entire guest suite'],
    'Private Room': ['Private room in home', 'Private room in rental unit', 'Private room in townhouse', 
                     'Private room in condo', 'Private room in bed and breakfast', 'Private room', 
                     'Private room in guest suite', 'Private room in tiny home', 'Private room in guesthouse', 
                     'Private room in loft', 'Private room in serviced apartment', 'Private room in hostel', 
                     'Private room in camper/rv', 'Private room in cabin', 'Private room in yurt', 
                     'Private room in hut', 'Private room in castle', 'Private room in casa particular', 
                     'Private room in bungalow'],
    'Shared Room': ['Shared room in rental unit', 'Shared room in home'],
    'Hotel Room': ['Room in serviced apartment', 'Room in hotel', 'Room in boutique hotel', 
                   'Room in aparthotel'],
    'Other': ['Tiny home', 'Camper/RV', 'Treehouse', 'Barn', 'Houseboat', 'Religious building']
        }

# 反转映射
dict2 = {i: k for k, v in dict1.items() for i in v}

# 替换并计算
data_need['property_type_group'] = data_need['property_type'].replace(dict2)
print(data_need['property_type_group'].value_counts())
# Out:
# Entire Apartment    983
# Private Room        644
# Entire Home         490
# Other               29
# Hotel Room          16
# Entire place        4
# Shared Room         3
# Name: property_type_group, dtype: int64

# %%
# split bathroom_text

def extract_bath_info(bathrooms_text):
    if pd.isna(bathrooms_text):
        return pd.Series([0, 0])
    
    # 提取浴室数量
    bath_count = 0
    shared_bath_count = 0
    
    # 提取半浴室情况
    if 'half' in bathrooms_text.lower():
        return pd.Series([shared_bath_count, bath_count])
    
    # 提取浴室数量和类型
    match = re.match(r'(\d*\.?\d*)\s?(shared|private)?\s?bath(s)?', bathrooms_text.lower())
    if match:
        bath_count = float(match.group(1)) if match.group(1) else 0
        if match.group(2) == 'shared':
            shared_bath_count = bath_count
            bath_count = 0

    return pd.Series([shared_bath_count, bath_count])

data_need[['shared_bath_count', 'bath_count']] = data_need['bathrooms_text'].apply(extract_bath_info)

print(data_need[['bathrooms_text', 'shared_bath_count', 'bath_count']])
# Out:
#         bathrooms_text  shared_bath_count  bath_count
# 0     1 shared bath     1.0                0.0
# 1     2.5 shared baths  2.5                0.0
# 2     1 shared bath     1.0                0.0
# 3     1.5 shared baths  1.5                0.0
# 4     1 shared bath     1.0                0.0
# ...             ...     ...                ...
# 2551  2 baths           0.0                2.0
# 2552  1 bath            0.0                1.0
# 2553  1 bath            0.0                1.0
# 2554  2 baths           0.0                2.0
# 2555  1 bath            0.0                1.0
#
# [2169 rows x 3 columns]

# %%
data_need['price'] = data_need['price'].str.replace('$', '', regex=False).str.replace(',', '', regex=False).astype(float)

# %%
data_need.head(3)
# Out:
#    neighbourhood_cleansed host_is_superhost              property_type  \
# 0  Windmill Hill           f                 Private room in townhouse
# 1  Hotwells & Harbourside  t                 Private room in condo
# 2  Southville              t                 Private room in townhouse
#
#       room_type    bathrooms_text  beds  minimum_nights  number_of_reviews  \
# 0  Private room  1 shared bath     1.0   3               189
# 1  Private room  2.5 shared baths  1.0   1               180
# 2  Private room  1 shared bath     1.0   5               53
#
#    number_of_reviews_ltm last_review  ...  \
# 0  11                     2023-11-29  ...
# 1  9                      2023-11-26  ...
# 2  10                     2023-12-12  ...
#
#   calculated_host_listings_count_entire_homes  \
# 0  0
# 1  0
# 2  0
#
#    calculated_host_listings_count_private_rooms  \
# 0  5
# 1  1
# 2  1
#
#    calculated_host_listings_count_shared_rooms  accommodates  price  rating  \
# 0  0                                            2             44.0   4.77
# 1  0                                            2             111.0  4.96
# 2  0                                            2             35.0   4.79
#
#    bedroom  property_type_group shared_bath_count  bath_count
# 0  1        Private Room         1.0               0.0
# 1  1        Private Room         2.5               0.0
# 2  1        Private Room         1.0               0.0
#
# [3 rows x 31 columns]

# %%
data_need = data_need.drop(['property_type','bathrooms_text'], axis=1)

# %%
data_need.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2167 entries, 0 to 2555
# Data columns (total 30 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   neighbourhood_cleansed                        2167 non-null   object
#  1   host_is_superhost                             2165 non-null   object
#  2   room_type                                     2167 non-null   object
#  3   beds                                          2119 non-null   float64
#  4   minimum_nights                                2167 non-null   int64
#  5   number_of_reviews                             2167 non-null   int64
#  6   number_of_reviews_ltm                         2167 non-null   int64
#  7   last_review                                   1887 non-null   object
#  8   first_review                                  1887 non-null   object
#  9   review_scores_rating                          1887 non-null   float64
#  10  review_scores_accuracy                        1886 non-null   float64
#  11  review_scores_cleanliness                     1886 non-null   float64
#  12  review_scores_checkin                         1886 non-null   float64
#  13  review_scores_communication                   1886 non-null   float64
#  14  review_scores_location                        1886 non-null   float64
#  15  review_scores_value                           1886 non-null   float64
#  16  instant_bookable                              2167 non-null   object
#  17  reviews_per_month                             1887 non-null   float64
#  18  calculated_host_listings_count                2167 non-null   int64
#  19  calculated_host_listings_count_entire_homes   2167 non-null   int64
#  20  calculated_host_listings_count_private_rooms  2167 non-null   int64
#  21  calculated_host_listings_count_shared_rooms   2167 non-null   int64
#  22  accommodates                                  2167 non-null   int64
#  23  price                                         2167 non-null   float64
#  24  rating                                        1680 non-null   object
#  25  bedroom                                       2071 non-null   object
#  26  property_type_group                           2167 non-null   object
#  27  shared_bath_count                             2167 non-null   float64
#  28  bath_count                                    2167 non-null   float64
#  29  log_price                                     2167 non-null   float64
# dtypes: float64(13), int64(8), object(9)
# memory usage: 524.8+ KB

# %%
col_to_fillna_most_frequent = ['beds', 'bedroom', 'host_is_superhost']
col_to_fillna_mean = ['review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness',
                      'review_scores_checkin', 'review_scores_communication', 'review_scores_location',
                      'review_scores_value', 'reviews_per_month']
col_to_getdummies = ['property_type_group', 'room_type', 'instant_bookable']
col_no_change = ['accommodates', 'number_of_reviews', 'number_of_reviews_ltm', 'minimum_nights',
                 'calculated_host_listings_count', 'calculated_host_listings_count_entire_homes',
                 'calculated_host_listings_count_private_rooms', 'calculated_host_listings_count_shared_rooms',
                 'shared_bath_count', 'bath_count']

# %%
plt.figure(figsize=(10, 6))
plt.hist(data_need['price'], bins=50, color='blue', edgecolor='black')
plt.title('Distribution of Airbnb Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.yscale('log')  # Using a log scale for better visualization of the distribution
plt.show()

# %%
high_price_listings = data_need[data_need['price'] > 2000]
high_price_listings.head()
# Out:
#      neighbourhood_cleansed host_is_superhost        room_type  beds  \
# 1562  Brislington East       f                 Entire home/apt  15.0
# 1783  Lockleaze              f                 Entire home/apt  6.0
#
#       minimum_nights  number_of_reviews  number_of_reviews_ltm last_review  \
# 1562  2               5                  5                      2023-11-19
# 1783  1               1                  1                      2023-02-05
#
#      first_review  review_scores_rating  ...  \
# 1562  2023-07-03   5.0                   ...
# 1783  2023-02-05   5.0                   ...
#
#       calculated_host_listings_count_entire_homes  \
# 1562  1
# 1783  2
#
#       calculated_host_listings_count_private_rooms  \
# 1562  0
# 1783  0
#
#       calculated_host_listings_count_shared_rooms  accommodates    price  \
# 1562  0                                            16            2214.0
# 1783  0                                            8             11499.0
#
#       rating bedroom  property_type_group  shared_bath_count  bath_count
# 1562  5.0     13      Entire Home          0.0                15.0
# 1783  None    3       Entire Home          0.0                1.0
#
# [2 rows x 29 columns]

# %%
data_need['price'].describe()
# Out:
# count    2167.000000
# mean     127.510383
# std      123.448206
# min      15.000000
# 25%      60.000000
# 50%      98.000000
# 75%      146.000000
# max      1286.000000
# Name: price, dtype: float64

# %%
data_need.head(3)
# Out:
#    neighbourhood_cleansed host_is_superhost     room_type  beds  \
# 0  Windmill Hill           f                 Private room  1.0
# 1  Hotwells & Harbourside  t                 Private room  1.0
# 2  Southville              t                 Private room  1.0
#
#    minimum_nights  number_of_reviews  number_of_reviews_ltm last_review  \
# 0  3               189                11                     2023-11-29
# 1  1               180                9                      2023-11-26
# 2  5               53                 10                     2023-12-12
#
#   first_review  review_scores_rating  ...  \
# 0  2013-10-18   4.77                  ...
# 1  2011-07-04   4.96                  ...
# 2  2012-11-18   4.79                  ...
#
#    calculated_host_listings_count_private_rooms  \
# 0  5
# 1  1
# 2  1
#
#    calculated_host_listings_count_shared_rooms  accommodates  price  rating  \
# 0  0                                            2             44.0   4.77
# 1  0                                            2             111.0  4.96
# 2  0                                            2             35.0   4.79
#
#    bedroom property_type_group  shared_bath_count  bath_count  log_price
# 0  1        Private Room        1.0                0.0         3.806662
# 1  1        Private Room        2.5                0.0         4.718499
# 2  1        Private Room        1.0                0.0         3.583519
#
# [3 rows x 30 columns]

# %%
data_need = data_need.drop(data_need[data_need['price'] > 2000].index)

# %% [markdown]
# # explore data
#
# Minimally skewed and showing insignificant kurtosis (<1) this passes the spot check for normal distribution (bell-shaped, symmetrical about the center). Likewise, our probability plot appears linear and reinforces our decision to leave log_price as-is.

# %%
data_need['log_price'] = np.log1p(data_need['price'])

# %%
# 对 price 列应用对数变换
data_need['log_price'] = np.log1p(data_need['price'])

# 绘制直方图并拟合正态分布曲线
sns.histplot(data_need['log_price'], kde=False, stat="density", linewidth=0)
plt.xlabel('log_price')
plt.ylabel('Density')
plt.title('Histogram of log_price with Normal Distribution Fit')

# 在直方图上叠加正态分布曲线
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, data_need['log_price'].mean(), data_need['log_price'].std())
plt.plot(x, p, 'k', linewidth=2)

# 显示直方图
plt.show()

# 绘制正态概率图
fig = plt.figure()
res = probplot(data_need['log_price'], plot=plt)
plt.title('Normal Q-Q plot of log_price')
plt.show()

# 计算变换后的偏度和峰度
print("Skewness: %f" % data_need['log_price'].skew())
print("Kurtosis: %f" % data_need['log_price'].kurt())
# Out:
# Skewness: 0.477380
# Kurtosis: 0.648204

# %%
sns.set(font_scale=0.6)
plt.figure(figsize=(8, 8))

corrmat = data_need.corr(numeric_only=True)

sns.heatmap(corrmat, cmap="seismic", annot=True, vmin=-1, vmax=1)
plt.title('Correlation Matrix')
plt.show()

# %%
plt.figure(figsize=(10, 10))

corrmat = data_need.corr(numeric_only=True)

# 选择与 log_price 的相关性，排序并绘制水平条形图
corrmat["log_price"].sort_values().plot(kind="barh")
plt.title('Correlation with log_price')
plt.show()
